# %% [markdown]
# ## Pandas install

# %%
# %pip install pandas numpy matplotlib.pyplot
# Out:
# Requirement already satisfied: pandas in c:\users\mahdi\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\mahdi\anaconda3\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot

# %% [markdown]
# ### Import pandas and read from csv

# %%
# TODO: Importera pandas
import pandas as pd

# !pwd
# %cd "../data"
# TODO: Ladda in data från CSV-fil
df = pd.read_csv('winequality-red.csv')

# TODO: Visa första 5 raderna
df.head()

# TODO: Visa antal rader och kolumner
df.shape

# TODO: Lista alla kolumner
df.columns
# Out:
# /workspaces/Big_data_py/tst/mini-projekt
# /workspaces/Big_data_py/tst/data
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ### Find nans and duplicated

# %%
# TODO: Kolla efter saknade värden
display(df.isna().sum())

# TODO: Kolla efter duplikater
df.duplicated().sum()
dups = df[df.duplicated()]

# TODO: Visa statistik för numeriska kolumner
df.describe
# TODO: Kolla efter outliers (extremvärden)
for key in df.columns:
    data = df[f"{key}"].dropna()
    data_extrem = (data.values > data.mean).sum()
    print(f"  • data that are outliears {data_extrem} (impossiable!)")
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      11 for key in df.columns:
#      12     data = df[f"{key}"].dropna()
# ---> 13     data_extrem = (data.values > data.mean).sum()
#      14     print(f"  • data that are outliears {data_extrem} (impossiable!)")
#
# TypeError: '>' not supported between instances of 'float' and 'method'

# %% [markdown]
# ### Import matplotlib and do data analys

# %%
# TODO: Importera matplotlib
import matplotlib.pyplot as plt

# TODO: Gör din analys här
'fixed acidity,volatile acidity,citric acid,residual sugar,'
'chlorides,free sulfur dioxide,total sulfur dioxide,density,'
'pH,sulphates,alcohol,quality'

# TODO: Skapa en graf
# Out:
# 'pH,sulphates,alcohol,quality'

# %% [markdown]
# ### Import sklearn

# %%
# TODO: Importera sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

# TODO: Välj features (X) och target (Y)
# X = 
# Y = 

# TODO: Dela data i träning och test (80/20)

# %% [markdown]
# ### make moduls

# %%
# TODO: Skapa modellen


# TODO: Träna modellen


# TODO: Gör prediktioner på testdata

# %%
# TODO: Beräkna R² score


# TODO: Beräkna MAE (Mean Absolute Error)


# TODO: Skapa en graf som visar prediktioner vs verkliga värden
